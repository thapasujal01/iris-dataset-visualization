# %% [markdown]
# <a href="https://colab.research.google.com/github/thapasujal01/iris-dataset-visualization/blob/main/table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
table_3_data = [
    ["Main character", "Daniel Radcliffe"],
    ["Sidekick 1", "Rupert Grint"],
    ["Sidekick 2", "Emma Watson"],
    ["Lovable ogre", "Robbie Coltrane"],
    ["Professor", "Maggie Smith"],
    ["Headmaster", "Richard Harris"]
]

formatted_table = [{"Role": row[0], "Actor": row[1]} for row in table_3_data]
