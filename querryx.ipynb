# %% [markdown]
# <a href="https://colab.research.google.com/github/thapasujal01/iris-dataset-visualization/blob/main/querryx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. AUTHENTICATION & SETUP
from google.colab import auth
auth.authenticate_user()
from google.cloud import bigquery
import pandas as pd

project_id = 'bike-shareanalysis'
client = bigquery.Client(project=project_id)

query = """
SELECT
    start_station_name,
    ROUND(AVG(duration_minutes), 2) AS avg_duration_mins,
    COUNT(*) AS total_trips
FROM
    `bigquery-public-data.austin_bikeshare.bikeshare_trips`
GROUP BY
    start_station_name
ORDER BY
    total_trips DESC
"""

df = client.query(query).to_dataframe()

busiest = df.iloc[0]['start_station_name']
print(f"The starting point with the most trips is: {busiest}")
# Out:
# The starting point with the most trips is: 21st/Speedway @ PCL
